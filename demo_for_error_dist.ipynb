# %%
from numpy import *
import numpy as np
import matplotlib.pyplot as plt
from Error_dist import error_dist, func_str

# %%
# Plot mapping between random number (-1 to 1) and error distribution

f = func_str(error_dist)  # Get function as a string

x = linspace(-1, 1, 1000)
plt.title(f)
plt.plot(x, eval(f))
plt.show()

# %%
# Plot error distribution
plt.title("Error distribution")
plt.hist(error_dist(100000), 50)
plt.show()

# %%
n = 100000
x = error_dist(n)
print(f"Probability for deviation < 0.5 max is {len(list(filter(lambda x: x > -0.5 and x < 0.5, x))) / n * 100}%")

# Alternatively we can filter with numpy:
# y = x[where(x < 0.5)]
# z = y[where(y > -0.5)]
# len(z)
# Out:
# Probability for deviation < 0.5 max is 83.38499999999999%
